# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('output/2023-12-01_00-38-20-555/scores.csv')
df
# Out:
#           i         train           val
# 0         0  7.200480e+12  7.200480e+12
# 1      1000  2.466806e+11  2.463154e+11
# 2      2000  8.109786e+10  8.102681e+10
# 3      3000  3.783836e+10  3.781272e+10
# 4      4000  2.023496e+10  2.022314e+10
# ..      ...           ...           ...
# 96    96000  9.917145e+01  7.753989e+01
# 97    97000  9.917145e+01  7.753886e+01
# 98    98000  9.917148e+01  7.754185e+01
# 99    99000  9.917148e+01  7.754025e+01
# 100  100000  9.917155e+01  7.754039e+01
#
# [101 rows x 3 columns]

# %%
plt.plot(df['i'], df['train'], label='train')
plt.plot(df['i'], df['val'], label='val')

# %%
plt.plot(df['i'], df['val'] - df['train'])
plt.show()

# %%
plt.plot(df['val'].pct_change())
plt.show()

# %%
df['val'].pct_change().iloc[54:56]
# Out:
# 54   -0.000668
# 55   -0.000002
# Name: val, dtype: float64

# %%
# optimal early stopping threshold:
1e-4
# Out:
# 0.0001

# %%
df['val'].pct_change().iloc[54]
