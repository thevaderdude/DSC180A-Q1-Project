# %%
# !python src/main.py  --seed 1 \
                     --d 20 \
                     --graph_type ER \
                     --degree 4 \
                     --noise_type gaussian_ev \
                     --equal_variances \
                     --lambda_1 2e-2 \
                     --lambda_2 5.0 \
                     --checkpoint_iter 1000 \
                     --early_stop_delta 1e-4
# Out:
# 2023-12-01 01:12:06,941 INFO - __main__ - Finished setting up the logger.
# 2023-12-01 01:12:07,010 INFO - numexpr.utils - NumExpr defaulting to 8 threads.
# 2023-12-01 01:12:07,205 INFO - __main__ - Finished loading the dataset.
# 2023-12-01 01:12:07,448 INFO - trainers.golem_trainer - Started training for 100000.0 iterations.
# 2023-12-01 01:12:07,451 INFO - trainers.golem_trainer - TRAINING: [Iter 0] score 7.200E+12, likelihood 1.385E+02, h 1.440E+12
# 2023-12-01 01:12:07,451 INFO - trainers.golem_trainer - VALIDATION: [Iter 0] score 7.200E+12, likelihood 1.167E+02, h 1.440E+12
# 2023-12-01 01:12:08,268 INFO - trainers.golem_trainer - TRAINING: [Iter 1000] score 2.467E+11, likelihood 1.384E+02, h 4.934E+10
# 2023-12-01 01:12:08,268 INFO - trainers.golem_trainer - VALIDATION: [Iter 1000] score 2.463E+11, likelihood 1.167E+02, h 4.926E+10
# 2023-12-01 01:12:09,031 INFO - trainers.golem_trainer - TRAINING: [Iter 2000] score 8.110E+10, likelihood 1.384E+02, h 1.622E+10
# ...

# %% [markdown]
# **We have effectively cut the training time in half with early stopping!**
