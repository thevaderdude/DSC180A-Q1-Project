# %% [markdown]
# ## TODO explain metrics
# fdr: (reverse + false positive) / prediction positive.
#
# tpr: (true positive) / condition positive.
#
# fpr: (reverse + false positive) / condition negative.
#
# shd: undirected extra + undirected missing + reverse.
#
# pred_size: prediction positive
#
# aupr:
#
# shd:
#
# Description of output of each call

# %% [markdown]
# # Demo of GOLEM-EV
#
# Dataset configurations:
# - Ground truth: 20-node ER2 graph
# - Data: Linear DAG model with Gaussian-EV noise.

# %%
# !python3 src/main.py --method GOLEM \
                     --seed 1 \
                     --d 10 \
                     --graph_type ER \
                     --degree 4 \
                     --noise_type gaussian_ev \
                     --equal_variances \
                     --lambda_1 2e-2 \
                     --lambda_2 5.0 \
                     --checkpoint_iter 5000
# Out:
# No GPU automatically detected. Setting SETTINGS.GPU to 0, and SETTINGS.NJOBS to cpu_count.
# 2023-12-08 09:17:19,632 INFO - __main__ - Finished setting up the logger.
# 2023-12-08 09:17:19,634 INFO - __main__ - Finished loading the dataset.
# 2023-12-08 09:17:19,745 INFO - trainers.golem_trainer - Started training for 100000.0 iterations.
# 2023-12-08 09:17:19,768 INFO - trainers.golem_trainer - [Iter 0] score 6.202E+01, likelihood 6.202E+01, h 0.000E+00
# 2023-12-08 09:17:20,943 INFO - trainers.golem_trainer - [Iter 5000] score 4.657E+01, likelihood 4.601E+01, h 7.572E-04
# 2023-12-08 09:17:22,143 INFO - trainers.golem_trainer - [Iter 10000] score 4.657E+01, likelihood 4.600E+01, h 5.894E-04
# 2023-12-08 09:17:23,351 INFO - trainers.golem_trainer - [Iter 15000] score 4.657E+01, likelihood 4.600E+01, h 5.732E-04
# 2023-12-08 09:17:24,560 INFO - trainers.golem_trainer - [Iter 20000] score 4.657E+01, likelihood 4.600E+01, h 5.684E-04
# 2023-12-08 09:17:25,776 INFO - trainers.golem_trainer - [Iter 25000] score 4.657E+01, likelihood 4.600E+01, h 5.836E-04
# 2023-12-08 09:17:26,999 INFO - trainers.golem_trainer - [Iter 30000] score 4.657E+01, likelihood 4.600E+01, h 5.684E-04
# 2023-12-08 09:17:28,217 INFO - trainers.golem_trainer - [Iter 35000] score 4.657E+01, likelihood 4.600E+01, h 5.732E-04
# 2023-12-08 09:17:29,435 INFO - trainers.golem_trainer - [Iter 40000] score 4.657E+01, likelihood 4.600E+01, h 5.846E-04
# 2023-12-08 09:17:30,653 INFO - trainers.golem_trainer - [Iter 45000] score 4.657E+01, likelihood 4.600E+01, h 5.836E-04
# 2023-12-08 09:17:31,865 INFO - trainers.golem_trainer - [Iter 50000] score 4.657E+01, likelihood 4.600E+01, h 5.779E-04
# 2023-12-08 09:17:33,073 INFO - trainers.golem_trainer - [Iter 55000] score 4.657E+01, likelihood 4.600E+01, h 5.798E-04
# 2023-12-08 09:17:34,280 INFO - trainers.golem_trainer - [Iter 60000] score 4.657E+01, likelihood 4.600E+01, h 5.693E-04
# 2023-12-08 09:17:35,487 INFO - trainers.golem_trainer - [Iter 65000] score 4.657E+01, likelihood 4.600E+01, h 5.875E-04
# 2023-12-08 09:17:36,695 INFO - trainers.golem_trainer - [Iter 70000] score 4.657E+01, likelihood 4.600E+01, h 5.732E-04
# 2023-12-08 09:17:37,906 INFO - trainers.golem_trainer - [Iter 75000] score 4.657E+01, likelihood 4.600E+01, h 5.703E-04
# 2023-12-08 09:17:39,119 INFO - trainers.golem_trainer - [Iter 80000] score 4.657E+01, likelihood 4.600E+01, h 5.722E-04
# 2023-12-08 09:17:40,334 INFO - trainers.golem_trainer - [Iter 85000] score 4.657E+01, likelihood 4.600E+01, h 5.836E-04
# 2023-12-08 09:17:41,549 INFO - trainers.golem_trainer - [Iter 90000] score 4.657E+01, likelihood 4.600E+01, h 5.798E-04
# 2023-12-08 09:17:42,762 INFO - trainers.golem_trainer - [Iter 95000] score 4.657E+01, likelihood 4.600E+01, h 5.665E-04
# 2023-12-08 09:17:43,976 INFO - trainers.golem_trainer - [Iter 100000] score 4.657E+01, likelihood 4.600E+01, h 5.732E-04
# 2023-12-08 09:17:43,978 INFO - __main__ - Finished training the model.
# 2023-12-08 09:17:43,978 INFO - __main__ - Finished post-processing the estimated graph.
# 2023-12-08 09:17:44,320 INFO - __main__ - Finished plotting estimated graph (without post-processing).
# 2023-12-08 09:17:44,320 INFO - __main__ - Results (after post-processing): {'fdr': 0.0, 'tpr': 1.0, 'fpr': 0.0, 'shd': 0, 'pred_size': 24}.
# 2023-12-08 09:17:44,320 INFO - __main__ - Finished saving training outputs at output/2023-12-08_09-17-19-632.

# %% [markdown]
# # Demo of GOLEM-NV
#
# The optimization problem of GOLEM-NV is susceptible to local solutions, so we have to initialize it with the solution returned by GOLEM-EV.
#
# Dataset configurations:
# - Ground truth: 20-node ER2 graph
# - Data: Linear DAG model with Gaussian-NV noise.

# %%
# !python3 src/main.py  --method GOLEM \
                     --seed 1 \
                     --d 10 \
                     --graph_type ER \
                     --degree 4 \
                     --noise_type gaussian_nv \
                     --equal_variances \
                     --lambda_1 2e-2 \
                     --lambda_2 5.0 \
                     --checkpoint_iter 5000
# Out:
# No GPU automatically detected. Setting SETTINGS.GPU to 0, and SETTINGS.NJOBS to cpu_count.
# 2023-12-08 09:17:47,983 INFO - __main__ - Finished setting up the logger.
# 2023-12-08 09:17:47,986 INFO - __main__ - Finished loading the dataset.
# 2023-12-08 09:17:48,099 INFO - trainers.golem_trainer - Started training for 100000.0 iterations.
# 2023-12-08 09:17:48,121 INFO - trainers.golem_trainer - [Iter 0] score 6.712E+01, likelihood 6.712E+01, h 0.000E+00
# 2023-12-08 09:17:49,301 INFO - trainers.golem_trainer - [Iter 5000] score 5.048E+01, likelihood 4.987E+01, h 6.716E-03
# 2023-12-08 09:17:50,518 INFO - trainers.golem_trainer - [Iter 10000] score 5.048E+01, likelihood 4.987E+01, h 6.376E-03
# 2023-12-08 09:17:51,731 INFO - trainers.golem_trainer - [Iter 15000] score 5.048E+01, likelihood 4.987E+01, h 6.369E-03
# 2023-12-08 09:17:52,944 INFO - trainers.golem_trainer - [Iter 20000] score 5.048E+01, likelihood 4.987E+01, h 6.372E-03
# 2023-12-08 09:17:54,155 INFO - trainers.golem_trainer - [Iter 25000] score 5.048E+01, likelihood 4.987E+01, h 6.351E-03
# 2023-12-08 09:17:55,372 INFO - trainers.golem_trainer - [Iter 30000] score 5.048E+01, likelihood 4.987E+01, h 6.369E-03
# 2023-12-08 09:17:56,588 INFO - trainers.golem_trainer - [Iter 35000] score 5.048E+01, likelihood 4.987E+01, h 6.371E-03
# 2023-12-08 09:17:57,813 INFO - trainers.golem_trainer - [Iter 40000] score 5.048E+01, likelihood 4.987E+01, h 6.363E-03
# 2023-12-08 09:17:59,068 INFO - trainers.golem_trainer - [Iter 45000] score 5.048E+01, likelihood 4.987E+01, h 6.388E-03
# 2023-12-08 09:18:00,339 INFO - trainers.golem_trainer - [Iter 50000] score 5.048E+01, likelihood 4.987E+01, h 6.382E-03
# 2023-12-08 09:18:01,589 INFO - trainers.golem_trainer - [Iter 55000] score 5.048E+01, likelihood 4.987E+01, h 6.382E-03
# 2023-12-08 09:18:02,801 INFO - trainers.golem_trainer - [Iter 60000] score 5.048E+01, likelihood 4.987E+01, h 6.369E-03
# 2023-12-08 09:18:04,011 INFO - trainers.golem_trainer - [Iter 65000] score 5.048E+01, likelihood 4.987E+01, h 6.376E-03
# 2023-12-08 09:18:05,225 INFO - trainers.golem_trainer - [Iter 70000] score 5.048E+01, likelihood 4.987E+01, h 6.382E-03
# 2023-12-08 09:18:06,434 INFO - trainers.golem_trainer - [Iter 75000] score 5.048E+01, likelihood 4.987E+01, h 6.348E-03
# 2023-12-08 09:18:07,649 INFO - trainers.golem_trainer - [Iter 80000] score 5.048E+01, likelihood 4.987E+01, h 6.352E-03
# 2023-12-08 09:18:08,858 INFO - trainers.golem_trainer - [Iter 85000] score 5.048E+01, likelihood 4.987E+01, h 6.369E-03
# 2023-12-08 09:18:10,072 INFO - trainers.golem_trainer - [Iter 90000] score 5.048E+01, likelihood 4.987E+01, h 6.369E-03
# 2023-12-08 09:18:11,284 INFO - trainers.golem_trainer - [Iter 95000] score 5.048E+01, likelihood 4.987E+01, h 6.372E-03
# 2023-12-08 09:18:12,497 INFO - trainers.golem_trainer - [Iter 100000] score 5.048E+01, likelihood 4.987E+01, h 6.366E-03
# 2023-12-08 09:18:12,498 INFO - __main__ - Finished training the model.
# 2023-12-08 09:18:12,498 INFO - __main__ - Finished post-processing the estimated graph.
# 2023-12-08 09:18:12,831 INFO - __main__ - Finished plotting estimated graph (without post-processing).
# 2023-12-08 09:18:12,831 INFO - __main__ - Results (after post-processing): {'fdr': 0.08, 'tpr': 0.9583333333333334, 'fpr': 0.09523809523809523, 'shd': 2, 'pred_size': 25}.
# 2023-12-08 09:18:12,832 INFO - __main__ - Finished saving training outputs at output/2023-12-08_09-17-47-983.

# %% [markdown]
# ## First way to run GOLEM-NV with initialization
#
# Set `init` to `True`. By default, the code will load the estimated solution of the **latest** experiment (based on datetime) in the `output` directory.
#
# Please make sure the latest experiment indeed corresponds to GOLEM-EV with same dataset configurations.
#
# In this case, the code will load the solution from the previous experiment (i.e., `output/2023-12-08_07-47-04-572`), since it is the latest experiment.

# %%
# !python3 src/main.py  --method GOLEM \
                     --seed 1 \
                     --d 10 \
                     --graph_type ER \
                     --degree 4 \
                     --noise_type gaussian_nv \
                     --equal_variances \
                     --lambda_1 2e-2 \
                     --lambda_2 5.0 \
                     --checkpoint_iter 5000
# Out:
# No GPU automatically detected. Setting SETTINGS.GPU to 0, and SETTINGS.NJOBS to cpu_count.
# 2023-12-08 09:18:16,521 INFO - __main__ - Finished setting up the logger.
# 2023-12-08 09:18:16,523 INFO - __main__ - Finished loading the dataset.
# 2023-12-08 09:18:16,635 INFO - trainers.golem_trainer - Started training for 100000.0 iterations.
# 2023-12-08 09:18:16,658 INFO - trainers.golem_trainer - [Iter 0] score 6.712E+01, likelihood 6.712E+01, h 0.000E+00
# 2023-12-08 09:18:17,846 INFO - trainers.golem_trainer - [Iter 5000] score 5.048E+01, likelihood 4.987E+01, h 6.716E-03
# 2023-12-08 09:18:19,063 INFO - trainers.golem_trainer - [Iter 10000] score 5.048E+01, likelihood 4.987E+01, h 6.376E-03
# 2023-12-08 09:18:20,280 INFO - trainers.golem_trainer - [Iter 15000] score 5.048E+01, likelihood 4.987E+01, h 6.369E-03
# 2023-12-08 09:18:21,494 INFO - trainers.golem_trainer - [Iter 20000] score 5.048E+01, likelihood 4.987E+01, h 6.372E-03
# 2023-12-08 09:18:22,709 INFO - trainers.golem_trainer - [Iter 25000] score 5.048E+01, likelihood 4.987E+01, h 6.351E-03
# 2023-12-08 09:18:23,926 INFO - trainers.golem_trainer - [Iter 30000] score 5.048E+01, likelihood 4.987E+01, h 6.369E-03
# 2023-12-08 09:18:25,139 INFO - trainers.golem_trainer - [Iter 35000] score 5.048E+01, likelihood 4.987E+01, h 6.371E-03
# 2023-12-08 09:18:26,359 INFO - trainers.golem_trainer - [Iter 40000] score 5.048E+01, likelihood 4.987E+01, h 6.363E-03
# 2023-12-08 09:18:27,574 INFO - trainers.golem_trainer - [Iter 45000] score 5.048E+01, likelihood 4.987E+01, h 6.388E-03
# 2023-12-08 09:18:28,790 INFO - trainers.golem_trainer - [Iter 50000] score 5.048E+01, likelihood 4.987E+01, h 6.382E-03
# 2023-12-08 09:18:30,005 INFO - trainers.golem_trainer - [Iter 55000] score 5.048E+01, likelihood 4.987E+01, h 6.382E-03
# 2023-12-08 09:18:31,223 INFO - trainers.golem_trainer - [Iter 60000] score 5.048E+01, likelihood 4.987E+01, h 6.369E-03
# 2023-12-08 09:18:32,437 INFO - trainers.golem_trainer - [Iter 65000] score 5.048E+01, likelihood 4.987E+01, h 6.376E-03
# 2023-12-08 09:18:33,652 INFO - trainers.golem_trainer - [Iter 70000] score 5.048E+01, likelihood 4.987E+01, h 6.382E-03
# 2023-12-08 09:18:34,865 INFO - trainers.golem_trainer - [Iter 75000] score 5.048E+01, likelihood 4.987E+01, h 6.348E-03
# 2023-12-08 09:18:36,141 INFO - trainers.golem_trainer - [Iter 80000] score 5.048E+01, likelihood 4.987E+01, h 6.352E-03
# 2023-12-08 09:18:37,363 INFO - trainers.golem_trainer - [Iter 85000] score 5.048E+01, likelihood 4.987E+01, h 6.369E-03
# 2023-12-08 09:18:38,576 INFO - trainers.golem_trainer - [Iter 90000] score 5.048E+01, likelihood 4.987E+01, h 6.369E-03
# 2023-12-08 09:18:39,789 INFO - trainers.golem_trainer - [Iter 95000] score 5.048E+01, likelihood 4.987E+01, h 6.372E-03
# 2023-12-08 09:18:41,006 INFO - trainers.golem_trainer - [Iter 100000] score 5.048E+01, likelihood 4.987E+01, h 6.366E-03
# 2023-12-08 09:18:41,007 INFO - __main__ - Finished training the model.
# 2023-12-08 09:18:41,008 INFO - __main__ - Finished post-processing the estimated graph.
# 2023-12-08 09:18:41,346 INFO - __main__ - Finished plotting estimated graph (without post-processing).
# 2023-12-08 09:18:41,347 INFO - __main__ - Results (after post-processing): {'fdr': 0.08, 'tpr': 0.9583333333333334, 'fpr': 0.09523809523809523, 'shd': 2, 'pred_size': 25}.
# 2023-12-08 09:18:41,348 INFO - __main__ - Finished saving training outputs at output/2023-12-08_09-18-16-521.

# %%
# !python3 src/main.py  --method GOLEM \
                     --seed 1 \
                     --d 10 \
                     --graph_type ER \
                     --degree 4 \
                     --noise_type gaussian_nv \
                     --non_equal_variances \
                     --init \
                     --lambda_1 2e-3 \
                     --lambda_2 5.0 \
                     --checkpoint_iter 5000
# Out:
# No GPU automatically detected. Setting SETTINGS.GPU to 0, and SETTINGS.NJOBS to cpu_count.
# 2023-12-08 09:18:45,007 INFO - __main__ - Finished setting up the logger.
# 2023-12-08 09:18:45,009 INFO - __main__ - Finished loading the dataset.
# 2023-12-08 09:18:45,009 INFO - __main__ - Finished loading B_init from output/2023-12-08_09-18-16-521/B_est.npy.
# 2023-12-08 09:18:45,118 INFO - trainers.golem_trainer - Started training for 100000.0 iterations.
# 2023-12-08 09:18:45,141 INFO - trainers.golem_trainer - [Iter 0] score 3.819E+01, likelihood 3.810E+01, h 6.366E-03
# 2023-12-08 09:18:46,425 INFO - trainers.golem_trainer - [Iter 5000] score 3.814E+01, likelihood 3.808E+01, h 1.526E-05
# 2023-12-08 09:18:47,641 INFO - trainers.golem_trainer - [Iter 10000] score 3.814E+01, likelihood 3.808E+01, h 1.526E-05
# 2023-12-08 09:18:48,850 INFO - trainers.golem_trainer - [Iter 15000] score 3.814E+01, likelihood 3.808E+01, h 1.526E-05
# 2023-12-08 09:18:50,059 INFO - trainers.golem_trainer - [Iter 20000] score 3.814E+01, likelihood 3.808E+01, h 1.526E-05
# 2023-12-08 09:18:51,267 INFO - trainers.golem_trainer - [Iter 25000] score 3.814E+01, likelihood 3.808E+01, h 1.526E-05
# 2023-12-08 09:18:52,474 INFO - trainers.golem_trainer - [Iter 30000] score 3.814E+01, likelihood 3.808E+01, h 1.526E-05
# 2023-12-08 09:18:53,683 INFO - trainers.golem_trainer - [Iter 35000] score 3.814E+01, likelihood 3.808E+01, h 1.526E-05
# 2023-12-08 09:18:54,922 INFO - trainers.golem_trainer - [Iter 40000] score 3.814E+01, likelihood 3.808E+01, h 1.526E-05
# 2023-12-08 09:18:56,138 INFO - trainers.golem_trainer - [Iter 45000] score 3.814E+01, likelihood 3.808E+01, h 1.526E-05
# 2023-12-08 09:18:57,358 INFO - trainers.golem_trainer - [Iter 50000] score 3.814E+01, likelihood 3.808E+01, h 1.526E-05
# 2023-12-08 09:18:58,580 INFO - trainers.golem_trainer - [Iter 55000] score 3.814E+01, likelihood 3.808E+01, h 1.526E-05
# 2023-12-08 09:18:59,840 INFO - trainers.golem_trainer - [Iter 60000] score 3.814E+01, likelihood 3.808E+01, h 1.526E-05
# 2023-12-08 09:19:01,087 INFO - trainers.golem_trainer - [Iter 65000] score 3.814E+01, likelihood 3.808E+01, h 1.526E-05
# 2023-12-08 09:19:02,298 INFO - trainers.golem_trainer - [Iter 70000] score 3.814E+01, likelihood 3.808E+01, h 1.526E-05
# 2023-12-08 09:19:03,504 INFO - trainers.golem_trainer - [Iter 75000] score 3.814E+01, likelihood 3.808E+01, h 1.526E-05
# 2023-12-08 09:19:04,712 INFO - trainers.golem_trainer - [Iter 80000] score 3.814E+01, likelihood 3.808E+01, h 1.431E-05
# 2023-12-08 09:19:05,918 INFO - trainers.golem_trainer - [Iter 85000] score 3.814E+01, likelihood 3.808E+01, h 1.526E-05
# 2023-12-08 09:19:07,136 INFO - trainers.golem_trainer - [Iter 90000] score 3.814E+01, likelihood 3.808E+01, h 1.526E-05
# 2023-12-08 09:19:08,358 INFO - trainers.golem_trainer - [Iter 95000] score 3.814E+01, likelihood 3.808E+01, h 1.431E-05
# 2023-12-08 09:19:09,574 INFO - trainers.golem_trainer - [Iter 100000] score 3.814E+01, likelihood 3.808E+01, h 1.526E-05
# 2023-12-08 09:19:09,575 INFO - __main__ - Finished training the model.
# 2023-12-08 09:19:09,575 INFO - __main__ - Finished post-processing the estimated graph.
# 2023-12-08 09:19:09,917 INFO - __main__ - Finished plotting estimated graph (without post-processing).
# 2023-12-08 09:19:09,917 INFO - __main__ - Results (after post-processing): {'fdr': 0.08, 'tpr': 0.9583333333333334, 'fpr': 0.09523809523809523, 'shd': 2, 'pred_size': 25}.
# 2023-12-08 09:19:09,918 INFO - __main__ - Finished saving training outputs at output/2023-12-08_09-18-45-006.

# %% [markdown]
# ## Second way to run GOLEM-NV with initialization
#
# Set `init` to `True` and manually set `init_path` to the path of estimated solution (`.npy` file) by GOLEM-EV.
#
# In this case, we set `init_path` to `output/2023-12-08_08-03-42-085/B_est.npy`.

# %%
# !python3 src/main.py  --method GOLEM \
                     --seed 1 \
                     --d 10 \
                     --graph_type ER \
                     --degree 4 \
                     --noise_type gaussian_nv \
                     --non_equal_variances \
                     --init \
                     --init_path output/2023-12-08_08-03-42-085/B_est.npy \
                     --lambda_1 2e-3 \
                     --lambda_2 5.0 \
                     --checkpoint_iter 5000
# Out:
# No GPU automatically detected. Setting SETTINGS.GPU to 0, and SETTINGS.NJOBS to cpu_count.
# 2023-12-08 09:19:13,655 INFO - __main__ - Finished setting up the logger.
# 2023-12-08 09:19:13,657 INFO - __main__ - Finished loading the dataset.
# 2023-12-08 09:19:13,657 CRITICAL - utils.logger - Unhandled exception.
# Traceback (most recent call last):
#   File "/Users/tylergibbs/DSC180A-Q1-Project/DSC180A-Q1-Project/src/main.py", line 95, in <module>
#     main()
#   File "/Users/tylergibbs/DSC180A-Q1-Project/DSC180A-Q1-Project/src/main.py", line 54, in main
#     B_init = np.load('{}'.format(args.init_path))
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/lib/npyio.py", line 427, in load
#     fid = stack.enter_context(open(os_fspath(file), "rb"))
#                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'output/2023-12-08_08-03-42-085/B_est.npy'

# %% [markdown]
# ## Running GOLEM-EV with Using pyTorch implementation

# %%
# !python3 src/main.py  --method GOLEM_TORCH \
                     --seed 1 \
                     --d 10 \
                     --graph_type ER \
                     --degree 4 \
                     --noise_type gaussian_nv \
                     --equal_variances \
                     --lambda_1 2e-2 \
                     --lambda_2 5.0 \
                     --checkpoint_iter 5000
# Out:
# No GPU automatically detected. Setting SETTINGS.GPU to 0, and SETTINGS.NJOBS to cpu_count.
# 2023-12-08 09:19:17,491 INFO - __main__ - Finished setting up the logger.
# 2023-12-08 09:19:17,493 INFO - __main__ - Finished loading the dataset.
# 2023-12-08 09:19:17,608 INFO - trainers.golem_trainer_torch - Started training for 100000.0 iterations.
# 2023-12-08 09:19:17,608 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 0] score 3.600E+12, likelihood 6.661E+01, h 7.200E+11
# 2023-12-08 09:19:17,609 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 0] score 3.600E+12, likelihood 5.544E+01, h 7.200E+11
# 2023-12-08 09:19:19,837 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 5000] score 5.784E+09, likelihood 6.651E+01, h 1.157E+09
# 2023-12-08 09:19:19,837 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 5000] score 5.781E+09, likelihood 5.533E+01, h 1.156E+09
# 2023-12-08 09:19:22,071 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 10000] score 4.869E+08, likelihood 6.592E+01, h 9.739E+07
# 2023-12-08 09:19:22,071 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 10000] score 4.867E+08, likelihood 5.476E+01, h 9.734E+07
# 2023-12-08 09:19:24,279 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 15000] score 4.633E+07, likelihood 6.558E+01, h 9.265E+06
# 2023-12-08 09:19:24,279 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 15000] score 4.630E+07, likelihood 5.443E+01, h 9.261E+06
# 2023-12-08 09:19:26,476 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 20000] score 4.557E+06, likelihood 6.533E+01, h 9.113E+05
# 2023-12-08 09:19:26,476 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 20000] score 4.554E+06, likelihood 5.420E+01, h 9.109E+05
# 2023-12-08 09:19:28,686 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 25000] score 4.644E+05, likelihood 6.524E+01, h 9.287E+04
# 2023-12-08 09:19:28,686 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 25000] score 4.642E+05, likelihood 5.413E+01, h 9.282E+04
# 2023-12-08 09:19:30,882 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 30000] score 4.980E+04, likelihood 6.491E+01, h 9.946E+03
# 2023-12-08 09:19:30,882 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 30000] score 4.976E+04, likelihood 5.382E+01, h 9.942E+03
# 2023-12-08 09:19:33,122 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 35000] score 5.779E+03, likelihood 5.342E+01, h 1.145E+03
# 2023-12-08 09:19:33,122 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 35000] score 5.766E+03, likelihood 4.193E+01, h 1.144E+03
# 2023-12-08 09:19:35,340 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 40000] score 7.700E+02, likelihood 4.989E+01, h 1.439E+02
# 2023-12-08 09:19:35,340 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 40000] score 7.585E+02, likelihood 3.863E+01, h 1.438E+02
# 2023-12-08 09:19:37,551 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 45000] score 1.366E+02, likelihood 4.912E+01, h 1.744E+01
# 2023-12-08 09:19:37,551 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 45000] score 1.252E+02, likelihood 3.780E+01, h 1.743E+01
# 2023-12-08 09:19:39,701 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 50000] score 5.278E+01, likelihood 4.933E+01, h 5.860E-01
# 2023-12-08 09:19:39,701 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 50000] score 4.149E+01, likelihood 3.805E+01, h 5.853E-01
# 2023-12-08 09:19:41,910 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 55000] score 4.999E+01, likelihood 4.933E+01, h 1.458E-02
# 2023-12-08 09:19:41,910 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 55000] score 3.876E+01, likelihood 3.810E+01, h 1.457E-02
# 2023-12-08 09:19:44,109 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 60000] score 4.999E+01, likelihood 4.932E+01, h 1.476E-02
# 2023-12-08 09:19:44,109 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 60000] score 3.876E+01, likelihood 3.810E+01, h 1.477E-02
# 2023-12-08 09:19:46,306 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 65000] score 4.999E+01, likelihood 4.932E+01, h 1.476E-02
# 2023-12-08 09:19:46,306 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 65000] score 3.876E+01, likelihood 3.810E+01, h 1.478E-02
# 2023-12-08 09:19:48,498 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 70000] score 4.999E+01, likelihood 4.932E+01, h 1.474E-02
# 2023-12-08 09:19:48,498 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 70000] score 3.876E+01, likelihood 3.810E+01, h 1.478E-02
# 2023-12-08 09:19:50,694 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 75000] score 4.999E+01, likelihood 4.932E+01, h 1.479E-02
# 2023-12-08 09:19:50,694 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 75000] score 3.876E+01, likelihood 3.810E+01, h 1.480E-02
# 2023-12-08 09:19:52,900 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 80000] score 4.999E+01, likelihood 4.932E+01, h 1.478E-02
# 2023-12-08 09:19:52,900 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 80000] score 3.876E+01, likelihood 3.810E+01, h 1.477E-02
# 2023-12-08 09:19:55,097 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 85000] score 4.999E+01, likelihood 4.932E+01, h 1.477E-02
# 2023-12-08 09:19:55,097 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 85000] score 3.876E+01, likelihood 3.810E+01, h 1.478E-02
# 2023-12-08 09:19:57,312 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 90000] score 4.999E+01, likelihood 4.932E+01, h 1.479E-02
# 2023-12-08 09:19:57,312 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 90000] score 3.876E+01, likelihood 3.810E+01, h 1.477E-02
# 2023-12-08 09:19:59,525 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 95000] score 4.999E+01, likelihood 4.932E+01, h 1.479E-02
# 2023-12-08 09:19:59,525 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 95000] score 3.876E+01, likelihood 3.810E+01, h 1.477E-02
# 2023-12-08 09:20:01,721 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 100000] score 4.999E+01, likelihood 4.932E+01, h 1.478E-02
# 2023-12-08 09:20:01,721 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 100000] score 3.876E+01, likelihood 3.810E+01, h 1.475E-02
# 2023-12-08 09:20:01,722 INFO - __main__ - Finished training the model.
# 2023-12-08 09:20:01,722 INFO - __main__ - Finished post-processing the estimated graph.
# 2023-12-08 09:20:02,032 INFO - __main__ - Finished plotting estimated graph (without post-processing).
# 2023-12-08 09:20:02,032 INFO - __main__ - Results (after post-processing): {'fdr': 0.12, 'tpr': 0.9166666666666666, 'fpr': 0.14285714285714285, 'shd': 3, 'pred_size': 25}.
# 2023-12-08 09:20:02,033 INFO - __main__ - Finished saving training outputs at output/2023-12-08_09-19-17-491.

# %% [markdown]
# ## Running GOLEM-EV with Using pyTorch implementation

# %%
# !python3 src/main.py  --method GOLEM_TORCH \
                     --seed 1 \
                     --d 10 \
                     --graph_type ER \
                     --degree 4 \
                     --noise_type gaussian_nv \
                     --equal_variances \
                     --lambda_1 2e-2 \
                     --lambda_2 5.0 \
                     --checkpoint_iter 5000
# Out:
# No GPU automatically detected. Setting SETTINGS.GPU to 0, and SETTINGS.NJOBS to cpu_count.
# 2023-12-08 09:20:06,086 INFO - __main__ - Finished setting up the logger.
# 2023-12-08 09:20:06,088 INFO - __main__ - Finished loading the dataset.
# 2023-12-08 09:20:06,207 INFO - trainers.golem_trainer_torch - Started training for 100000.0 iterations.
# 2023-12-08 09:20:06,208 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 0] score 3.600E+12, likelihood 6.661E+01, h 7.200E+11
# 2023-12-08 09:20:06,208 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 0] score 3.600E+12, likelihood 5.544E+01, h 7.200E+11
# 2023-12-08 09:20:08,512 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 5000] score 5.784E+09, likelihood 6.651E+01, h 1.157E+09
# 2023-12-08 09:20:08,512 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 5000] score 5.781E+09, likelihood 5.533E+01, h 1.156E+09
# 2023-12-08 09:20:10,874 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 10000] score 4.869E+08, likelihood 6.592E+01, h 9.739E+07
# 2023-12-08 09:20:10,874 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 10000] score 4.867E+08, likelihood 5.476E+01, h 9.734E+07
# 2023-12-08 09:20:13,071 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 15000] score 4.633E+07, likelihood 6.558E+01, h 9.265E+06
# 2023-12-08 09:20:13,071 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 15000] score 4.630E+07, likelihood 5.443E+01, h 9.261E+06
# 2023-12-08 09:20:15,277 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 20000] score 4.557E+06, likelihood 6.533E+01, h 9.113E+05
# 2023-12-08 09:20:15,277 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 20000] score 4.554E+06, likelihood 5.420E+01, h 9.109E+05
# 2023-12-08 09:20:17,489 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 25000] score 4.644E+05, likelihood 6.524E+01, h 9.287E+04
# 2023-12-08 09:20:17,489 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 25000] score 4.642E+05, likelihood 5.413E+01, h 9.282E+04
# 2023-12-08 09:20:19,728 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 30000] score 4.980E+04, likelihood 6.491E+01, h 9.946E+03
# 2023-12-08 09:20:19,728 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 30000] score 4.976E+04, likelihood 5.382E+01, h 9.942E+03
# 2023-12-08 09:20:21,932 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 35000] score 5.779E+03, likelihood 5.342E+01, h 1.145E+03
# 2023-12-08 09:20:21,932 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 35000] score 5.766E+03, likelihood 4.193E+01, h 1.144E+03
# 2023-12-08 09:20:24,164 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 40000] score 7.700E+02, likelihood 4.989E+01, h 1.439E+02
# 2023-12-08 09:20:24,164 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 40000] score 7.585E+02, likelihood 3.863E+01, h 1.438E+02
# 2023-12-08 09:20:26,385 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 45000] score 1.366E+02, likelihood 4.912E+01, h 1.744E+01
# 2023-12-08 09:20:26,385 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 45000] score 1.252E+02, likelihood 3.780E+01, h 1.743E+01
# 2023-12-08 09:20:28,516 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 50000] score 5.278E+01, likelihood 4.933E+01, h 5.860E-01
# 2023-12-08 09:20:28,517 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 50000] score 4.149E+01, likelihood 3.805E+01, h 5.853E-01
# 2023-12-08 09:20:30,736 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 55000] score 4.999E+01, likelihood 4.933E+01, h 1.458E-02
# 2023-12-08 09:20:30,736 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 55000] score 3.876E+01, likelihood 3.810E+01, h 1.457E-02
# 2023-12-08 09:20:32,943 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 60000] score 4.999E+01, likelihood 4.932E+01, h 1.476E-02
# 2023-12-08 09:20:32,943 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 60000] score 3.876E+01, likelihood 3.810E+01, h 1.477E-02
# 2023-12-08 09:20:35,127 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 65000] score 4.999E+01, likelihood 4.932E+01, h 1.476E-02
# 2023-12-08 09:20:35,127 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 65000] score 3.876E+01, likelihood 3.810E+01, h 1.478E-02
# 2023-12-08 09:20:37,314 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 70000] score 4.999E+01, likelihood 4.932E+01, h 1.474E-02
# 2023-12-08 09:20:37,314 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 70000] score 3.876E+01, likelihood 3.810E+01, h 1.478E-02
# 2023-12-08 09:20:39,505 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 75000] score 4.999E+01, likelihood 4.932E+01, h 1.479E-02
# 2023-12-08 09:20:39,506 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 75000] score 3.876E+01, likelihood 3.810E+01, h 1.480E-02
# 2023-12-08 09:20:41,697 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 80000] score 4.999E+01, likelihood 4.932E+01, h 1.478E-02
# 2023-12-08 09:20:41,697 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 80000] score 3.876E+01, likelihood 3.810E+01, h 1.477E-02
# 2023-12-08 09:20:43,877 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 85000] score 4.999E+01, likelihood 4.932E+01, h 1.477E-02
# 2023-12-08 09:20:43,877 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 85000] score 3.876E+01, likelihood 3.810E+01, h 1.478E-02
# 2023-12-08 09:20:46,126 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 90000] score 4.999E+01, likelihood 4.932E+01, h 1.479E-02
# 2023-12-08 09:20:46,126 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 90000] score 3.876E+01, likelihood 3.810E+01, h 1.477E-02
# 2023-12-08 09:20:48,306 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 95000] score 4.999E+01, likelihood 4.932E+01, h 1.479E-02
# 2023-12-08 09:20:48,306 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 95000] score 3.876E+01, likelihood 3.810E+01, h 1.477E-02
# 2023-12-08 09:20:50,489 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 100000] score 4.999E+01, likelihood 4.932E+01, h 1.478E-02
# 2023-12-08 09:20:50,489 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 100000] score 3.876E+01, likelihood 3.810E+01, h 1.475E-02
# 2023-12-08 09:20:50,490 INFO - __main__ - Finished training the model.
# 2023-12-08 09:20:50,490 INFO - __main__ - Finished post-processing the estimated graph.
# 2023-12-08 09:20:50,834 INFO - __main__ - Finished plotting estimated graph (without post-processing).
# 2023-12-08 09:20:50,834 INFO - __main__ - Results (after post-processing): {'fdr': 0.12, 'tpr': 0.9166666666666666, 'fpr': 0.14285714285714285, 'shd': 3, 'pred_size': 25}.
# 2023-12-08 09:20:50,836 INFO - __main__ - Finished saving training outputs at output/2023-12-08_09-20-06-086.

# %% [markdown]
# ## Running GOLEM-NV with Early stop
#
# `early_stop_delta` is the value to stop at
# ## TODO reword

# %%
# !python3 src/main.py  --method GOLEM_TORCH \
                     --early_stop_delta 1e-4 \
                     --seed 1 \
                     --d 10 \
                     --graph_type ER \
                     --degree 4 \
                     --noise_type gaussian_nv \
                     --equal_variances \
                     --lambda_1 2e-2 \
                     --lambda_2 5.0 \
                     --checkpoint_iter 5000
# Out:
# No GPU automatically detected. Setting SETTINGS.GPU to 0, and SETTINGS.NJOBS to cpu_count.
# 2023-12-08 09:20:54,667 INFO - __main__ - Finished setting up the logger.
# 2023-12-08 09:20:54,669 INFO - __main__ - Finished loading the dataset.
# 2023-12-08 09:20:54,785 INFO - trainers.golem_trainer_torch - Started training for 100000.0 iterations.
# 2023-12-08 09:20:54,786 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 0] score 3.600E+12, likelihood 6.661E+01, h 7.200E+11
# 2023-12-08 09:20:54,786 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 0] score 3.600E+12, likelihood 5.544E+01, h 7.200E+11
# 2023-12-08 09:20:57,034 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 5000] score 5.784E+09, likelihood 6.651E+01, h 1.157E+09
# 2023-12-08 09:20:57,034 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 5000] score 5.781E+09, likelihood 5.533E+01, h 1.156E+09
# 2023-12-08 09:20:59,267 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 10000] score 4.869E+08, likelihood 6.592E+01, h 9.739E+07
# 2023-12-08 09:20:59,267 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 10000] score 4.867E+08, likelihood 5.476E+01, h 9.734E+07
# 2023-12-08 09:21:01,540 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 15000] score 4.633E+07, likelihood 6.558E+01, h 9.265E+06
# 2023-12-08 09:21:01,540 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 15000] score 4.630E+07, likelihood 5.443E+01, h 9.261E+06
# 2023-12-08 09:21:03,800 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 20000] score 4.557E+06, likelihood 6.533E+01, h 9.113E+05
# 2023-12-08 09:21:03,800 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 20000] score 4.554E+06, likelihood 5.420E+01, h 9.109E+05
# 2023-12-08 09:21:06,110 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 25000] score 4.644E+05, likelihood 6.524E+01, h 9.287E+04
# 2023-12-08 09:21:06,110 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 25000] score 4.642E+05, likelihood 5.413E+01, h 9.282E+04
# 2023-12-08 09:21:08,413 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 30000] score 4.980E+04, likelihood 6.491E+01, h 9.946E+03
# 2023-12-08 09:21:08,413 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 30000] score 4.976E+04, likelihood 5.382E+01, h 9.942E+03
# 2023-12-08 09:21:10,615 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 35000] score 5.779E+03, likelihood 5.342E+01, h 1.145E+03
# 2023-12-08 09:21:10,615 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 35000] score 5.766E+03, likelihood 4.193E+01, h 1.144E+03
# 2023-12-08 09:21:12,826 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 40000] score 7.700E+02, likelihood 4.989E+01, h 1.439E+02
# 2023-12-08 09:21:12,826 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 40000] score 7.585E+02, likelihood 3.863E+01, h 1.438E+02
# 2023-12-08 09:21:15,001 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 45000] score 1.366E+02, likelihood 4.912E+01, h 1.744E+01
# 2023-12-08 09:21:15,001 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 45000] score 1.252E+02, likelihood 3.780E+01, h 1.743E+01
# 2023-12-08 09:21:17,188 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 50000] score 5.278E+01, likelihood 4.933E+01, h 5.860E-01
# 2023-12-08 09:21:17,188 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 50000] score 4.149E+01, likelihood 3.805E+01, h 5.853E-01
# 2023-12-08 09:21:19,430 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 55000] score 4.999E+01, likelihood 4.933E+01, h 1.458E-02
# 2023-12-08 09:21:19,430 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 55000] score 3.876E+01, likelihood 3.810E+01, h 1.457E-02
# Early Stop: p: -2.1653142539435066e-05, i: 60000, loss: 38.7572021484375
# 2023-12-08 09:21:21,658 INFO - __main__ - Finished training the model.
# 2023-12-08 09:21:21,659 INFO - __main__ - Finished post-processing the estimated graph.
# 2023-12-08 09:21:21,969 INFO - __main__ - Finished plotting estimated graph (without post-processing).
# 2023-12-08 09:21:21,969 INFO - __main__ - Results (after post-processing): {'fdr': 0.12, 'tpr': 0.9166666666666666, 'fpr': 0.14285714285714285, 'shd': 3, 'pred_size': 25}.
# 2023-12-08 09:21:21,970 INFO - __main__ - Finished saving training outputs at output/2023-12-08_09-20-54-667.

# %% [markdown]
# # Demo of DAGMA
#
# Dataset configurations:
# - Ground truth: 20-node ER2 graph
# - Data: Linear DAG model with Gaussian-EV noise.

# %%
# !python3 src/main.py  --method DAGMA \
                     --seed 1 \
                     --d 10 \
                     --graph_type ER \
                     --degree 4 \
                     --noise_type gaussian_ev \
                     --equal_variances \
                     --checkpoint_iter 1000 \
                     --loss l2
# Out:
# No GPU automatically detected. Setting SETTINGS.GPU to 0, and SETTINGS.NJOBS to cpu_count.
# 2023-12-08 09:21:25,702 INFO - __main__ - Finished setting up the logger.
# 2023-12-08 09:21:25,703 INFO - __main__ - Finished loading the dataset.
# 100%|█████████████████████████████| 180000/180000.0 [00:00<00:00, 241654.47it/s]
# 2023-12-08 09:21:26,456 INFO - __main__ - Finished training the model.
# 2023-12-08 09:21:26,456 INFO - __main__ - Finished post-processing the estimated graph.
# 2023-12-08 09:21:26,680 INFO - __main__ - Finished plotting estimated graph (without post-processing).
# 2023-12-08 09:21:26,680 INFO - __main__ - Results (after post-processing): {'fdr': 0.0, 'tpr': 1.0, 'fpr': 0.0, 'shd': 0, 'pred_size': 24}.
# 2023-12-08 09:21:26,681 INFO - __main__ - Finished saving training outputs at output/2023-12-08_09-21-25-701.

# %% [markdown]
# # Demo of NOTEARS
#
# Dataset configurations:
# - Ground truth: 20-node ER2 graph
# - Data: Linear DAG model with Gaussian-EV noise.

# %%
# !python3 src/main.py  --method NOTEARS \
                     --seed 1 \
                     --d 10 \
                     --graph_type ER \
                     --degree 4 \
                     --noise_type gaussian_ev \
                     --equal_variances \
                     --lambda_1 2e-2 \
                     --loss l2
# Out:
# No GPU automatically detected. Setting SETTINGS.GPU to 0, and SETTINGS.NJOBS to cpu_count.
# 2023-12-08 09:21:30,389 INFO - __main__ - Finished setting up the logger.
# 2023-12-08 09:21:30,391 INFO - __main__ - Finished loading the dataset.
# 2023-12-08 09:21:31,102 INFO - __main__ - Finished training the model.
# 2023-12-08 09:21:31,102 INFO - __main__ - Finished post-processing the estimated graph.
# 2023-12-08 09:21:31,416 INFO - __main__ - Finished plotting estimated graph (without post-processing).
# 2023-12-08 09:21:31,416 INFO - __main__ - Results (after post-processing): {'fdr': 0.08, 'tpr': 0.9583333333333334, 'fpr': 0.09523809523809523, 'shd': 2, 'pred_size': 25}.
# 2023-12-08 09:21:31,417 INFO - __main__ - Finished saving training outputs at output/2023-12-08_09-21-30-389.

# %% [markdown]
# ## Comparisons between methods
#
# In this section we look at how the different methods compare on a variety of generated datasets
#
# We examine respectivly
# - GOLEM
# - GOLEM with early stop
# - DAGMA linear case
# - DAGMA non linear case
# - NOTEARS linear case
# - NOTEARS non linear case

# %%
from src.compare import compare
from src.data_loader.synthetic_dataset import SyntheticDataset
from src.data_loader.sachs_dataset import getSacksDataset
# Out:
# No GPU automatically detected. Setting SETTINGS.GPU to 0, and SETTINGS.NJOBS to cpu_count.

# %%
seed = 1
num_iter = 1e+5
learning_rate=1e-3

output_dir = "output"

# %%
examples = 10
d = 6
degree = 3


dataset = SyntheticDataset(examples, d, 'ER', 
                           degree, 'gaussian_ev', 
                           3, seed)

compare(dataset, nonlinear=True, dims=[d,1],output_dir=output_dir,
        equal_variances = True,num_iter = 1e+5,learning_rate=1e-3)
# Out:
# original golem
# modified golem
#   0%|          | 0/180000.0 [00:00<?, ?it/s]
# linear dagma
#   0%|          | 0/230000.0 [00:00<?, ?it/s]
# nonlinear dagma
# linear notears
# nonlinear notears

# %%
examples = 1000
d = 6
degree = 3


dataset = SyntheticDataset(examples, d, 'ER', 
                           degree, 'gaussian_ev', 
                           3, seed)
compare(dataset, nonlinear=True, dims=[d,3,1],output_dir=output_dir,
        equal_variances = True,num_iter = 1e+5,learning_rate=1e-3)
# Out:
# original golem
# modified golem
#   0%|          | 0/180000.0 [00:00<?, ?it/s]
# linear dagma
#   0%|          | 0/230000.0 [00:00<?, ?it/s]
# nonlinear dagma
# linear notears
# nonlinear notears

# %%
examples = 1000
d = 6
degree = 5


dataset = SyntheticDataset(examples, d, 'ER', 
                           degree, 'gaussian_ev', 
                           3, seed)
compare(dataset, nonlinear=True, dims=[d,3,1],output_dir=output_dir,
        equal_variances = True,num_iter = 1e+5,learning_rate=1e-3)
# Out:
# original golem
# modified golem
#   0%|          | 0/180000.0 [00:00<?, ?it/s]
# linear dagma
#   0%|          | 0/230000.0 [00:00<?, ?it/s]
# nonlinear dagma
# linear notears
# nonlinear notears

# %%
examples = 1000
d = 12
degree = 5


dataset = SyntheticDataset(examples, d, 'ER', 
                           degree, 'gaussian_ev', 
                           3, seed)
compare(dataset, nonlinear=True, dims=[d,3,1],output_dir=output_dir,
        equal_variances = True,num_iter = 1e+5,learning_rate=1e-3)
# Out:
# original golem
# modified golem
#   0%|          | 0/180000.0 [00:00<?, ?it/s]
# linear dagma
#   0%|          | 0/230000.0 [00:00<?, ?it/s]
# nonlinear dagma
# linear notears
# overflow encountered in matmul
# nonlinear notears

# %%
examples = 1000
d = 12
degree = 10


dataset = SyntheticDataset(examples, d, 'ER', 
                           degree, 'gaussian_ev', 
                           3, seed)
compare(dataset, nonlinear=True, dims=[d,3,1],output_dir=output_dir,
        equal_variances = True, num_iter = 1e+5,learning_rate=1e-3)
# Out:
# original golem
# modified golem
#   0%|          | 0/180000.0 [00:00<?, ?it/s]
# linear dagma
#   0%|          | 0/230000.0 [00:00<?, ?it/s]
# nonlinear dagma
# linear notears
# nonlinear notears

# %% [markdown]
# ## Sacks Dataset
#
# The Sachs dataset is a dataset that measures the expression levels of various proteins and phospholipids in human cells and is widely used in causality studies.
#
# We will examine the performence of our methods on this read world dataset, because of the data size we will not run notears or nonlinear dagma on it. This constrain further emphisizes the need for more efficiant methods we will explore in our second quarter project.

# %%
dataset = getSacksDataset()
compare(dataset, output_dir=output_dir, notears=False)
# Out:
# original golem
# modified golem
#   0%|          | 0/180000.0 [00:00<?, ?it/s]
# linear dagma

# %% [markdown]
# ## Loss Analysis for early stopping threashold
#
# # TODO I dont know how any of this works

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from src.utils.utils import get_init_path

# %%
# !python3 src/main.py  --method GOLEM_TORCH \
                     --seed 1 \
                     --d 10 \
                     --graph_type ER \
                     --degree 4 \
                     --noise_type gaussian_nv \
                     --equal_variances \
                     --lambda_1 2e-2 \
                     --lambda_2 5.0 \
                     --checkpoint_iter 5000
# Out:
# No GPU automatically detected. Setting SETTINGS.GPU to 0, and SETTINGS.NJOBS to cpu_count.
# 2023-12-08 10:45:12,301 INFO - __main__ - Finished setting up the logger.
# 2023-12-08 10:45:12,303 INFO - __main__ - Finished loading the dataset.
# 2023-12-08 10:45:12,436 INFO - trainers.golem_trainer_torch - Started training for 100000.0 iterations.
# 2023-12-08 10:45:12,437 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 0] score 3.600E+12, likelihood 6.661E+01, h 7.200E+11
# 2023-12-08 10:45:12,437 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 0] score 3.600E+12, likelihood 5.544E+01, h 7.200E+11
# 2023-12-08 10:45:14,701 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 5000] score 5.784E+09, likelihood 6.651E+01, h 1.157E+09
# 2023-12-08 10:45:14,701 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 5000] score 5.781E+09, likelihood 5.533E+01, h 1.156E+09
# 2023-12-08 10:45:16,875 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 10000] score 4.869E+08, likelihood 6.592E+01, h 9.739E+07
# 2023-12-08 10:45:16,875 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 10000] score 4.867E+08, likelihood 5.476E+01, h 9.734E+07
# 2023-12-08 10:45:19,040 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 15000] score 4.633E+07, likelihood 6.558E+01, h 9.265E+06
# 2023-12-08 10:45:19,040 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 15000] score 4.630E+07, likelihood 5.443E+01, h 9.261E+06
# 2023-12-08 10:45:21,257 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 20000] score 4.557E+06, likelihood 6.533E+01, h 9.113E+05
# 2023-12-08 10:45:21,257 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 20000] score 4.554E+06, likelihood 5.420E+01, h 9.109E+05
# 2023-12-08 10:45:23,518 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 25000] score 4.644E+05, likelihood 6.524E+01, h 9.287E+04
# 2023-12-08 10:45:23,518 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 25000] score 4.642E+05, likelihood 5.413E+01, h 9.282E+04
# 2023-12-08 10:45:25,799 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 30000] score 4.980E+04, likelihood 6.491E+01, h 9.946E+03
# 2023-12-08 10:45:25,799 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 30000] score 4.976E+04, likelihood 5.382E+01, h 9.942E+03
# 2023-12-08 10:45:28,035 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 35000] score 5.779E+03, likelihood 5.342E+01, h 1.145E+03
# 2023-12-08 10:45:28,035 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 35000] score 5.766E+03, likelihood 4.193E+01, h 1.144E+03
# 2023-12-08 10:45:30,263 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 40000] score 7.700E+02, likelihood 4.989E+01, h 1.439E+02
# 2023-12-08 10:45:30,263 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 40000] score 7.585E+02, likelihood 3.863E+01, h 1.438E+02
# 2023-12-08 10:45:32,527 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 45000] score 1.366E+02, likelihood 4.912E+01, h 1.744E+01
# 2023-12-08 10:45:32,527 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 45000] score 1.252E+02, likelihood 3.780E+01, h 1.743E+01
# 2023-12-08 10:45:34,702 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 50000] score 5.278E+01, likelihood 4.933E+01, h 5.860E-01
# 2023-12-08 10:45:34,702 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 50000] score 4.149E+01, likelihood 3.805E+01, h 5.853E-01
# 2023-12-08 10:45:36,921 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 55000] score 4.999E+01, likelihood 4.933E+01, h 1.458E-02
# 2023-12-08 10:45:36,921 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 55000] score 3.876E+01, likelihood 3.810E+01, h 1.457E-02
# 2023-12-08 10:45:39,140 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 60000] score 4.999E+01, likelihood 4.932E+01, h 1.476E-02
# 2023-12-08 10:45:39,140 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 60000] score 3.876E+01, likelihood 3.810E+01, h 1.477E-02
# 2023-12-08 10:45:41,349 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 65000] score 4.999E+01, likelihood 4.932E+01, h 1.476E-02
# 2023-12-08 10:45:41,349 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 65000] score 3.876E+01, likelihood 3.810E+01, h 1.478E-02
# 2023-12-08 10:45:43,561 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 70000] score 4.999E+01, likelihood 4.932E+01, h 1.474E-02
# 2023-12-08 10:45:43,562 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 70000] score 3.876E+01, likelihood 3.810E+01, h 1.478E-02
# 2023-12-08 10:45:45,746 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 75000] score 4.999E+01, likelihood 4.932E+01, h 1.479E-02
# 2023-12-08 10:45:45,747 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 75000] score 3.876E+01, likelihood 3.810E+01, h 1.480E-02
# 2023-12-08 10:45:48,013 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 80000] score 4.999E+01, likelihood 4.932E+01, h 1.478E-02
# 2023-12-08 10:45:48,013 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 80000] score 3.876E+01, likelihood 3.810E+01, h 1.477E-02
# 2023-12-08 10:45:50,253 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 85000] score 4.999E+01, likelihood 4.932E+01, h 1.477E-02
# 2023-12-08 10:45:50,253 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 85000] score 3.876E+01, likelihood 3.810E+01, h 1.478E-02
# 2023-12-08 10:45:52,454 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 90000] score 4.999E+01, likelihood 4.932E+01, h 1.479E-02
# 2023-12-08 10:45:52,454 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 90000] score 3.876E+01, likelihood 3.810E+01, h 1.477E-02
# 2023-12-08 10:45:54,649 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 95000] score 4.999E+01, likelihood 4.932E+01, h 1.479E-02
# 2023-12-08 10:45:54,649 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 95000] score 3.876E+01, likelihood 3.810E+01, h 1.477E-02
# 2023-12-08 10:45:56,830 INFO - trainers.golem_trainer_torch - TRAINING: [Iter 100000] score 4.999E+01, likelihood 4.932E+01, h 1.478E-02
# 2023-12-08 10:45:56,830 INFO - trainers.golem_trainer_torch - VALIDATION: [Iter 100000] score 3.876E+01, likelihood 3.810E+01, h 1.475E-02
# 2023-12-08 10:45:56,830 INFO - __main__ - Finished training the model.
# 2023-12-08 10:45:56,830 INFO - __main__ - Finished post-processing the estimated graph.
# 2023-12-08 10:45:57,196 INFO - __main__ - Finished plotting estimated graph (without post-processing).
# 2023-12-08 10:45:57,196 INFO - __main__ - Results (after post-processing): {'fdr': 0.12, 'tpr': 0.9166666666666666, 'fpr': 0.14285714285714285, 'shd': 3, 'pred_size': 25}.
# 2023-12-08 10:45:57,197 INFO - __main__ - Finished saving training outputs at output/2023-12-08_10-45-12-301.

# %%
from glob import glob

path = '{}/scores.csv'.format(sorted(glob('{}/*'.format('output')))[-1])

df = pd.read_csv(path)
df
# Out:
#          i         train           val
# 0        0  3.600240e+12  3.600240e+12
# 1     5000  5.784360e+09  5.781249e+09
# 2    10000  4.869355e+08  4.867042e+08
# 3    15000  4.632525e+07  4.630364e+07
# 4    20000  4.556548e+06  4.554434e+06
# 5    25000  4.643997e+05  4.641793e+05
# 6    30000  4.979771e+04  4.976477e+04
# 7    35000  5.779445e+03  5.765540e+03
# 8    40000  7.700151e+02  7.584659e+02
# 9    45000  1.365820e+02  1.252194e+02
# 10   50000  5.277660e+01  4.148775e+01
# 11   55000  4.998632e+01  3.875804e+01
# 12   60000  4.998618e+01  3.875720e+01
# 13   65000  4.998619e+01  3.875747e+01
# 14   70000  4.998620e+01  3.875752e+01
# 15   75000  4.998621e+01  3.875718e+01
# 16   80000  4.998618e+01  3.875742e+01
# 17   85000  4.998620e+01  3.875773e+01
# 18   90000  4.998621e+01  3.875794e+01
# 19   95000  4.998621e+01  3.875727e+01
# 20  100000  4.998620e+01  3.875767e+01

# %%
plt.plot(df['i'], df['train'], label='train')
plt.plot(df['i'], df['val'], label='val')

# %%
plt.plot(df['i'], df['val'] - df['train'])
plt.show()

# %%
plt.plot(df['val'].pct_change())
plt.show()

# %%
df['val'].pct_change().iloc[54:56]
# Out:
# Series([], Name: val, dtype: float64)

# %%
# optimal early stopping threshold:
1e-4
# Out:
# 0.0001
